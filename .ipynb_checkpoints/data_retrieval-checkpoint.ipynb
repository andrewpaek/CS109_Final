# %%
########## SET-UP ##########

# necessary libraries
import os
import json
import requests
import time
import datetime

# INSERT YOUR API KEY HERE! DO NOT USE MINE! (Sean)
KEY = 'b00c992b-6fc1-4795-abcc-7db85c1b72fa'

# %%
# MATCH-v2.2
REGION_ENDPOINT = "https://{0}.api.pvp.net/api/lol/{0}/"

# FUNCTION TO PULL MATCH DATA
def get_match(REGION, matchId, includeTimeline):
    """
    Retrieve match by match ID.
    """
    return requests.get(
        (REGION_ENDPOINT + "v2.2/match/{1}?"
         "api_key={2}&includeTimeline={3}").
        format(REGION, matchId, KEY, includeTimeline))

# %%
# Constants
STATUS_OK = 200
STATUS_RATE_LIMIT_EXCEEDED = 429
valid_rank_games = ['RANKED_SOLO_5x5',  # Ranked Solo 5v5 games
                    'RANKED_PREMADE_5x5',  # Ranked Premade 5v5 games
                    'RANKED_TEAM_5x5']  # Ranked Team 5v5 games

REGION_list = ['na', 'kr', 'eune', 'euw', 'lan', 'las', 'oce', 'ru', 'br', 'tr']

# Sean
regional_match_id = {'na': 2029998508, 
                     'kr': 2192853175,   #캬하하
                     'br': 667070117,    #brTT
                     'eune': 1297475846, #PaiNkiller Gr3k
                     'euw': 2416866695,  #Arceo
                     'lan': 229957555,   #Malvado
                     'las': 273069741,   #Tea
                     'oce': 113869146,   #Talk Sleek
                     'ru': 84050035,     #bronyaw
                     'tr': 325243355}    #kua

# COMMENT OUT regional_match_id THAT IS NOT UNDER YOUR NAME!!!!!!!!!!!!!!!!!!
# DO NOT RUN THIS PART OF THE CODE AFTER YOU'VE STARTED THE LOOP BELOW. IT'LL OVERWRITE EXISTING DATA!!!

# jaemin
#regional_match_id = {'na': 2029960687,
#                     'kr': 2192916925,
#                     'br': 664106032,
#                     'eune': 1293871277,
#                     'euw': 2417718483,
#                     'lan': 229932736,
#                     'las': 271679926,
#                     'oce': 113897495,
#                     'ru': 83927963,
#                     'tr': 332060998}
                     
# kenny
#regional_match_id = {'na': 2029894256
#                     'kr': 2181887785
#                     'br': 664332857
#                     'eune': 1293801833
#                     'euw': 2417655730
#                     'lan': 229928986
#                     'las': 272582143
#                     'oce': 113887342
#                     'ru': 83706280
#                     'tr': 332046148}

# andrew
#regional_match_id = {'na': 2029848145
#                     'kr': 2181825342
#                     'br': 664520626
#                     'eune': 1293842842
#                     'euw': 2416827654
#                     'lan': 229859020
#                     'las': 272319645
#                     'oce': 113877802
#                     'ru': 84139484
#                     'tr': 331322838}

# andrew_new
# regional_match_id = {'na': 
#                     'kr': 2191725864
#                     'br': 657525985
#                     'eune': 1296975996
#                     'euw': 
#                     'lan': 230046764
#                     'las': 272799452
#                     'oce': 
#                     'ru': 83843684
#                     'tr': }

# %%
# Functions that check status of the data pulls
def isValid(match):
    if match.status_code != STATUS_OK:
        return False
    return True

def isClassicMatch(match):
    j = match.json()
    if j['mapId'] == 11 and j['matchMode'] == "CLASSIC" and j['matchType'] == 'MATCHED_GAME':
        return True
    else:
        return False

def isRankMatch(match):
    j = match.json()
    if j['queueType'] in valid_rank_games:
        return True
    else:
        return False
                    
def rateLimitExceeded(match):
    if int(match.status_code) == STATUS_RATE_LIMIT_EXCEEDED:
        return True
    return False

# %%
# initializing indices
i, n, r = (0, 0, 0) # i = incrementing starting match ID, n = number of games retrieved, r = region list index)


# feel free to stop/run this loop anytime (it remembers the last starting point.. but it doesn't hurt to double check)
for k in range(100000):
    # current region
    curr_region = REGION_list[r]
    current_match_id = regional_match_id[curr_region] + i
    i += 1
    
    m = get_match(curr_region, current_match_id, False)
    
    if not rateLimitExceeded(m):
        if isValid(m) and isClassicMatch(m) and isRankMatch(m):

            f = open("dump_global/" + str(curr_region) + str(current_match_id) + ".json", 'w+')
            # if your name is Jaemin, use this part
            #f = open("dump_jaemin_global/" + str(current_match_id)+".json", 'w+')
            # if your name is Kenny, use this part
            #f = open("dump_kenny_global/" + str(current_match_id)+".json", 'w+')
            # if your name is Andrew, use this part
            #f = open("dump_andrew_global/" + str(current_match_id)+".json", 'w+')
            f.write(m.text.encode('utf-8'))
            n += 1
            print 'n: %d, ts: %s, ID: %d, date: %s, season: %s, tier: %s, loop_index: %d, region: %s' % (n, datetime.datetime.fromtimestamp(time.time()).strftime('%H:%M:%S'), 
                                                                                                 current_match_id, 
                                                                                                 ('%s' % (time.strftime('%m-%d', time.localtime(m.json()['matchCreation']/1000)))),
                                                                                                 m.json()['season'], m.json()['participants'][1]['highestAchievedSeasonTier'], k,
                                                                                                            m.json()['region'])
            f.close()
    else:
        regional_match_id[curr_region] =  current_match_id + i
        if (r == 9):
            print ("rate limit reached at %s, moving onto %s") % (REGION_list[r], REGION_list[0])
            r = 0
        else:
            print ("rate limit reached at %s, moving onto %s") % (REGION_list[r], REGION_list[r+1])
            r += 1
        i = 0
        # My computer was slow at writing JSON files, so it took 10 seconds to come back to the same region
        # If you're computer is super fast, uncomment the time.sleep below (you probably shouldn't)
        #time.sleep(1)
# Out:
# rate limit reached at na, moving onto kr
# n: 1, ts: 20:11:32, ID: 2192853175, date: 12-06, season: PRESEASON2016, tier: DIAMOND, loop_index: 11, region: KR
# n: 2, ts: 20:11:34, ID: 2192853177, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 13, region: KR
# n: 3, ts: 20:11:35, ID: 2192853178, date: 12-06, season: PRESEASON2016, tier: PLATINUM, loop_index: 14, region: KR
# n: 4, ts: 20:11:36, ID: 2192853179, date: 12-06, season: PRESEASON2016, tier: BRONZE, loop_index: 15, region: KR
# n: 5, ts: 20:11:38, ID: 2192853181, date: 12-06, season: PRESEASON2016, tier: UNRANKED, loop_index: 17, region: KR
# n: 6, ts: 20:11:39, ID: 2192853182, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 18, region: KR
# n: 7, ts: 20:11:40, ID: 2192853183, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 19, region: KR
# n: 8, ts: 20:11:41, ID: 2192853184, date: 12-06, season: PRESEASON2016, tier: PLATINUM, loop_index: 20, region: KR
# rate limit reached at kr, moving onto eune
# n: 9, ts: 20:11:42, ID: 1297475846, date: 12-06, season: PRESEASON2016, tier: DIAMOND, loop_index: 22, region: EUNE
# n: 10, ts: 20:11:43, ID: 1297475848, date: 12-06, season: PRESEASON2016, tier: BRONZE, loop_index: 24, region: EUNE
# n: 11, ts: 20:11:44, ID: 1297475851, date: 12-06, season: PRESEASON2016, tier: UNRANKED, loop_index: 27, region: EUNE
# rate limit reached at eune, moving onto euw
# n: 12, ts: 20:11:47, ID: 2416866695, date: 12-05, season: PRESEASON2016, tier: DIAMOND, loop_index: 33, region: EUW
# n: 13, ts: 20:11:47, ID: 2416866696, date: 12-05, season: PRESEASON2016, tier: UNRANKED, loop_index: 34, region: EUW
# rate limit reached at euw, moving onto lan
# n: 14, ts: 20:11:52, ID: 229957555, date: 12-05, season: PRESEASON2016, tier: CHALLENGER, loop_index: 42, region: LAN
# n: 15, ts: 20:11:53, ID: 229957557, date: 12-05, season: PRESEASON2016, tier: BRONZE, loop_index: 44, region: LAN
# rate limit reached at lan, moving onto las
# n: 16, ts: 20:11:57, ID: 273069741, date: 12-06, season: PRESEASON2016, tier: CHALLENGER, loop_index: 53, region: LAS
# n: 17, ts: 20:11:57, ID: 273069742, date: 12-06, season: PRESEASON2016, tier: GOLD, loop_index: 54, region: LAS
# rate limit reached at las, moving onto oce
# n: 18, ts: 20:12:04, ID: 113869602, date: 12-02, season: PRESEASON2016, tier: GOLD, loop_index: 70, region: OCE
# n: 19, ts: 20:12:05, ID: 113869604, date: 12-02, season: PRESEASON2016, tier: SILVER, loop_index: 72, region: OCE
# rate limit reached at oce, moving onto ru
# n: 20, ts: 20:12:07, ID: 84050035, date: 12-01, season: PRESEASON2016, tier: MASTER, loop_index: 75, region: RU
# rate limit reached at ru, moving onto br
# n: 21, ts: 20:12:13, ID: 667070117, date: 12-06, season: PRESEASON2016, tier: DIAMOND, loop_index: 86, region: BR
# n: 22, ts: 20:12:14, ID: 667070119, date: 12-06, season: PRESEASON2016, tier: GOLD, loop_index: 88, region: BR
# n: 23, ts: 20:12:14, ID: 667070120, date: 12-06, season: PRESEASON2016, tier: BRONZE, loop_index: 89, region: BR
# n: 24, ts: 20:12:16, ID: 667070123, date: 12-06, season: PRESEASON2016, tier: BRONZE, loop_index: 92, region: BR
# rate limit reached at br, moving onto tr
# n: 25, ts: 20:12:20, ID: 325243748, date: 11-14, season: PRESEASON2016, tier: SILVER, loop_index: 101, region: TR
# n: 26, ts: 20:12:21, ID: 325243749, date: 11-14, season: PRESEASON2016, tier: BRONZE, loop_index: 102, region: TR
# n: 27, ts: 20:12:21, ID: 325243750, date: 11-14, season: PRESEASON2016, tier: SILVER, loop_index: 103, region: TR
# rate limit reached at tr, moving onto na
# n: 28, ts: 20:12:24, ID: 2029998987, date: 12-06, season: PRESEASON2016, tier: UNRANKED, loop_index: 108, region: NA
# rate limit reached at na, moving onto kr
# n: 29, ts: 20:12:29, ID: 2192853196, date: 12-06, season: PRESEASON2016, tier: BRONZE, loop_index: 119, region: KR
# n: 30, ts: 20:12:31, ID: 2192853198, date: 12-06, season: PRESEASON2016, tier: BRONZE, loop_index: 121, region: KR
# n: 31, ts: 20:12:32, ID: 2192853199, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 122, region: KR
# n: 32, ts: 20:12:33, ID: 2192853200, date: 12-06, season: PRESEASON2016, tier: GOLD, loop_index: 123, region: KR
# n: 33, ts: 20:12:34, ID: 2192853201, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 124, region: KR
# n: 34, ts: 20:12:37, ID: 2192853204, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 127, region: KR
# rate limit reached at kr, moving onto eune
# n: 35, ts: 20:12:41, ID: 1297475872, date: 12-06, season: PRESEASON2016, tier: PLATINUM, loop_index: 135, region: EUNE
# n: 36, ts: 20:12:41, ID: 1297475873, date: 12-06, season: PRESEASON2016, tier: UNRANKED, loop_index: 136, region: EUNE
# n: 37, ts: 20:12:42, ID: 1297475874, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 137, region: EUNE
# n: 38, ts: 20:12:43, ID: 1297475876, date: 12-06, season: PRESEASON2016, tier: BRONZE, loop_index: 139, region: EUNE
# rate limit reached at eune, moving onto euw
# n: 39, ts: 20:12:45, ID: 2416866715, date: 12-05, season: PRESEASON2016, tier: GOLD, loop_index: 144, region: EUW
# n: 40, ts: 20:12:46, ID: 2416866716, date: 12-05, season: PRESEASON2016, tier: SILVER, loop_index: 145, region: EUW
# n: 41, ts: 20:12:47, ID: 2416866717, date: 12-05, season: PRESEASON2016, tier: SILVER, loop_index: 146, region: EUW
# n: 42, ts: 20:12:48, ID: 2416866719, date: 12-05, season: PRESEASON2016, tier: SILVER, loop_index: 148, region: EUW
# rate limit reached at euw, moving onto lan
# rate limit reached at lan, moving onto las
# n: 43, ts: 20:12:53, ID: 273069769, date: 12-06, season: PRESEASON2016, tier: UNRANKED, loop_index: 159, region: LAS
# rate limit reached at las, moving onto oce
# rate limit reached at oce, moving onto ru
# rate limit reached at ru, moving onto br
# n: 44, ts: 20:13:07, ID: 667070138, date: 12-06, season: PRESEASON2016, tier: GOLD, loop_index: 185, region: BR
# n: 45, ts: 20:13:09, ID: 667070141, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 188, region: BR
# n: 46, ts: 20:13:09, ID: 667070142, date: 12-06, season: PRESEASON2016, tier: BRONZE, loop_index: 189, region: BR
# rate limit reached at br, moving onto tr
# n: 47, ts: 20:13:13, ID: 325243765, date: 11-14, season: PRESEASON2016, tier: PLATINUM, loop_index: 196, region: TR
# n: 48, ts: 20:13:13, ID: 325243766, date: 11-14, season: PRESEASON2016, tier: PLATINUM, loop_index: 197, region: TR
# n: 49, ts: 20:13:14, ID: 325243767, date: 11-14, season: PRESEASON2016, tier: BRONZE, loop_index: 198, region: TR
# n: 50, ts: 20:13:15, ID: 325243769, date: 11-14, season: PRESEASON2016, tier: SILVER, loop_index: 200, region: TR
# rate limit reached at tr, moving onto na
# rate limit reached at na, moving onto kr
# n: 51, ts: 20:13:22, ID: 2192853217, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 210, region: KR
# n: 52, ts: 20:13:23, ID: 2192853218, date: 12-06, season: PRESEASON2016, tier: GOLD, loop_index: 211, region: KR
# n: 53, ts: 20:13:25, ID: 2192853219, date: 12-06, season: PRESEASON2016, tier: GOLD, loop_index: 212, region: KR
# n: 54, ts: 20:13:27, ID: 2192853220, date: 12-06, season: PRESEASON2016, tier: SILVER, loop_index: 213, region: KR

# %%
regional_match_id['kr'] = 2192853175
regional_match_id['br'] = 667070117
regional_match_id['eune'] = 1297475846
regional_match_id['euw'] = 2416866695
regional_match_id['lan'] = 229957555
regional_match_id['las'] = 273069741
regional_match_id['ru'] = 84050035
