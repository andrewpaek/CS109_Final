# %%
########## SET-UP ##########

# necessary libraries
import os
import json
import requests
import time
import datetime

# INSERT YOUR API KEY HERE
KEY = 'b00c992b-6fc1-4795-abcc-7db85c1b72fa'

# %%
# MATCH-v2.2

REGION_ENDPOINT = "https://{0}.api.pvp.net/api/lol/{0}/"

# FUNCTION TO PULL MATCH DATA
def get_match(REGION, matchId, includeTimeline):
    """
    Retrieve match by match ID.
    """
    return requests.get(
        (REGION_ENDPOINT + "v2.2/match/{1}?"
         "api_key={2}&includeTimeline={3}").
        format(REGION, matchId, KEY, includeTimeline))

# %%
# Constants
REGION = 'na'
STATUS_OK = 200
STATUS_RATE_LIMIT_EXCEEDED = 429
valid_rank_games = ['RANKED_SOLO_5x5',  # Ranked Solo 5v5 games
                    'RANKED_PREMADE_3x3',  # Ranked Premade 3v3 games
                    'RANKED_PREMADE_5x5',  # Ranked Premade 5v5 games
                    'RANKED_TEAM_3x3',  # Ranked Team 3v3 games
                    'RANKED_TEAM_5x5']  # Ranked Team 5v5 games

# Starting MatchID
# STARTING_MATCH_ID = 2026937783

################## UNCOMMENT AND DELETE IRRELEVANT PARTS HERE ###############

# List of starting MatchID's
# sean
match_id_list = [2029016554, 2028998508, 2028697992, 2028410883, 2028610390]
# jaemin
#match_id_list = [2028886202, 2028875395, 2028669368, 2028646565, 2028611382, 2026627159]
# lenny kei
#match_id_list = [2028144696, 2028076924, 2028017860, 2028129100, 2028115585, 2026610783]
# a paek
#match_id_list = [2028089458, 2027868106, 2027853644, 2027828374, 2026660053, 2026561470]

# Functions that check status of the data pulls
def isValid(match):
    if match.status_code != STATUS_OK:
        return False
    return True

def isClassicMatch(match):
    j = match.json()
    if j['mapId'] == 11 and j['matchMode'] == "CLASSIC" and j['matchType'] == 'MATCHED_GAME':
        return True
    else:
        return False

def isRankMatch(match):
    j = match.json()
    if j['queueType'] in valid_rank_games:
        return True
    else:
        return False
                    
def rateLimitExceeded(match):
    if int(match.status_code) == STATUS_RATE_LIMIT_EXCEEDED:
        return True
    return False

# index for the for-loop
i = 0
# counting the number of data retrieved
n = 0
# counting how many times we sleep in case we hit a dead-end
sleep_counter = 0

while i < 100000:
    # break out of the loop when there are no more match_id's left
    if match_id_list == []:
    print "ran out of starting match ID's. ending the loop"
    break
    
    # incrementing index
    i += 1
    #print ("i: %d, match_id: %d") % (i, match_id_list[0] + i)    
    
    current_match_id = match_id_list[0] + i
    m = get_match(REGION, current_match_id, True)
    
    if not rateLimitExceeded(m):
        if isValid(m) and isClassicMatch(m) and isRankMatch(m):
            
            ################## UNCOMMENT AND DELETE IRRELEVANT PARTS HERE ###############
            # if your name is sean, uncomment this
            f = open("dump/" + str(i + match_id_list[0])+".json", 'w+')
            # if you went to Kareoke Thursday night, uncomment this
            #f = open("dump_jaemin/" + str(i + STARTING_MATCH_ID)+".json", 'w+')
            # if your name is Lenny Key, uncomment this
            #f = open("dump_kenny/" + str(i + STARTING_MATCH_ID)+".json", 'w+')
            # if you're the dying president of Samsung, uncomment this
            #f = open("dump_andrew/" + str(i + STARTING_MATCH_ID)+".json", 'w+')
                     
            f.write(m.text.encode('utf-8'))
            n += 1
            print 'n: %d, ts: %s, gamdID: %d, date: %s, season: %s, tier: %s, loop_index: %d' % (n, datetime.datetime.fromtimestamp(time.time()).strftime('%m-%d %H:%M:%S'), 
                                                                                                 current_match_id, 
                                                                                                 ('%s' % (time.strftime('%m-%d', time.localtime(m.json()['matchCreation']/1000)))),
                                                                                                 m.json()['season'], m.json()['participants'][1]['highestAchievedSeasonTier'], i)
            f.close()
            # reset sleep_counter if we are get data again
            sleep_counter = 0
    else:
        sleep_counter += 1
        print("API rate limit reached - waiting 10 seconds, sleep count: %d, loop_index: %d") % (sleep_counter, i)
        time.sleep(10)
        
        # if we have to sleep 30 times, we will assume that we are in no man's land and move onto the next id on list
        if sleep_counter >= 30:
            del match_id_list[0]
            sleep_counter = 0
            i = 0
            print ("Seems like we hit a dead-end. Starting from the next match id on the list. new_starting_point: %d") % match_id_list[0]
# Out:
# i: 1, match_id: 2029016555
# n: 1, ts: 12-05 14:10:38, gamdID: 2029016555, date: 12-05, season: PRESEASON2016, tier: SILVER, loop_index: 1
# i: 2, match_id: 2029016556
# n: 2, ts: 12-05 14:10:39, gamdID: 2029016556, date: 12-05, season: PRESEASON2016, tier: SILVER, loop_index: 2
# i: 3, match_id: 2029016557
# i: 4, match_id: 2029016558
# i: 5, match_id: 2029016559
# i: 6, match_id: 2029016560
# n: 3, ts: 12-05 14:10:40, gamdID: 2029016560, date: 12-05, season: PRESEASON2016, tier: SILVER, loop_index: 6
# i: 7, match_id: 2029016561
# i: 8, match_id: 2029016562
# i: 9, match_id: 2029016563
# API rate limit reached - waiting 10 seconds, sleep count: 1, loop_index: 9
# i: 10, match_id: 2029016564
# n: 4, ts: 12-05 14:10:52, gamdID: 2029016564, date: 12-05, season: PRESEASON2016, tier: GOLD, loop_index: 10
# i: 11, match_id: 2029016565
# n: 5, ts: 12-05 14:10:53, gamdID: 2029016565, date: 12-05, season: PRESEASON2016, tier: SILVER, loop_index: 11
# i: 12, match_id: 2029016566
# i: 13, match_id: 2029016567
# i: 14, match_id: 2029016568
# i: 15, match_id: 2029016569
# i: 16, match_id: 2029016570
# i: 17, match_id: 2029016571
# i: 18, match_id: 2029016572
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-ebbcf31d913b> in <module>()
#      64     print ("i: %d, match_id: %d") % (i, match_id_list[0] + i)
#      65
# ---> 66     m = get_match(REGION, i + match_id_list[0], True)
#      67
#      68     if not rateLimitExceeded(m):
#
# <ipython-input-3-1efe5e365fdd> in get_match(REGION, matchId, includeTimeline)
#      11         (REGION_ENDPOINT + "v2.2/match/{1}?"
#      12          "api_key={2}&includeTimeline={3}").
# ---> 13         format(REGION, matchId, KEY, includeTimeline))
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      67
#      68     kwargs.setdefault('allow_redirects', True)
# ---> 69     return request('get', url, params=params, **kwargs)
#      70
#      71
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
#      52     # can trigger a ResourceWarning in some cases, and look like a memory leak
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     557             httplib_response = self._make_request(conn, method, url,
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#     561             # If we're going to release the connection in ``finally:``, then
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _validate_conn(self, conn)
#     780         # Force connect early to allow us to validate the connection.
#     781         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 782             conn.connect()
#     783
#     784         if not conn.is_verified:
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in connect(self)
#     213     def connect(self):
#     214         # Add certificate verification
# --> 215         conn = self._new_conn()
#     216
#     217         resolved_cert_reqs = resolve_cert_reqs(self.cert_reqs)
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connection.pyc in _new_conn(self)
#     133         try:
#     134             conn = connection.create_connection(
# --> 135                 (self.host, self.port), self.timeout, **extra_kw)
#     136
#     137         except SocketTimeout as e:
#
# /Users/seungjaecha/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/util/connection.pyc in create_connection(address, timeout, source_address, socket_options)
#      78             if source_address:
#      79                 sock.bind(source_address)
# ---> 80             sock.connect(sa)
#      81             return sock
#      82
#
# /Users/seungjaecha/anaconda/lib/python2.7/socket.pyc in meth(name, self, *args)
#     226
#     227 def meth(name,self,*args):
# --> 228     return getattr(self._sock,name)(*args)
#     229
#     230 for _m in _socketmethods:
#
# KeyboardInterrupt:
